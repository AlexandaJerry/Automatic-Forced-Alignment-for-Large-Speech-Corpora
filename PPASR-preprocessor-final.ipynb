# %% [markdown]
# ### 01 安装需要的依赖和部署预训练模型

# %%
# !python -m pip install paddlepaddle-gpu==2.4.1.post112 -f https://www.paddlepaddle.org.cn/whl/linux/mkl/avx/stable.html
# !python -m pip install ppasr
# !pip install pypinyin
# !python -m pip install paddlespeech-ctcdecoders
# !git clone https://github.com/AlexandaJerry/PPASR.git
# %cd /content/PPASR
# !python setup.py install

# %%
# !wget --load-cookies /tmp/cookies.txt "https://docs.google.com/uc?export=download&confirm=$(wget --quiet --save-cookies /tmp/cookies.txt --keep-session-cookies --no-check-certificate 'https://docs.google.com/uc?export=download&id=1e7t3lOPj0PAgQHWVot0dRw8_NRoP27IN' -O- | sed -rn 's/.*confirm=([0-9A-Za-z_]+).*/\1\n/p')&id=1e7t3lOPj0PAgQHWVot0dRw8_NRoP27IN" -O "PPASR.zip" && rm -rf /tmp/cookies.txt
# !unzip /content/PPASR/PPASR.zip -d /content
# !cp -RT /content/PPASR_V2-conformer_online-fbank-超大数据集/configs/ /content/PPASR/configs/
# !cp -RT /content/PPASR_V2-conformer_online-fbank-超大数据集/dataset/ /content/PPASR/dataset/
# !cp -RT /content/PPASR_V2-conformer_online-fbank-超大数据集/models/ /content/PPASR/models/
# %cd /content/PPASR
# !python export_model.py --resume_model=models/conformer_online_fbank/best_model/
# Out:
# Archive:  /content/PPASR/PPASR.zip
#    creating: /content/PPASR_V2-conformer_online-fbank-超大数据集/
#    creating: /content/PPASR_V2-conformer_online-fbank-超大数据集/configs/
#   inflating: /content/PPASR_V2-conformer_online-fbank-超大数据集/configs/conformer_online_zh.yml
#    creating: /content/PPASR_V2-conformer_online-fbank-超大数据集/dataset/
#   inflating: /content/PPASR_V2-conformer_online-fbank-超大数据集/dataset/mean_istd.json
#   inflating: /content/PPASR_V2-conformer_online-fbank-超大数据集/dataset/vocabulary.txt
#    creating: /content/PPASR_V2-conformer_online-fbank-超大数据集/models/
#    creating: /content/PPASR_V2-conformer_online-fbank-超大数据集/models/conformer_online_fbank/
#    creating: /content/PPASR_V2-conformer_online-fbank-超大数据集/models/conformer_online_fbank/best_model/
#   inflating: /content/PPASR_V2-conformer_online-fbank-超大数据集/models/conformer_online_fbank/best_model/model.pdparams

# %% [markdown]
# ---
#
#
#
# ---

# %% [markdown]
# ### 02 导入谷歌云盘中的音频压缩文件

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
wav_file = 'data.zip'#@param {type:"string"}
wav_path = "/content/drive/MyDrive/" + wav_file
# !unzip wav_path -d /content/PPASR/raw_wav

# %% [markdown]
# ---
#
#
#
# ---

# %% [markdown]
# ### 03 长音频自动切片为短音频

# %%
import glob
import os
import shutil
import wave

import librosa
import soundfile

def length(src: str):
    if os.path.isfile(src) and src.endswith('.wav'):
        with wave.open(src, 'r') as w:
            return w.getnframes() / w.getframerate() / 3600
    elif os.path.isdir(src):
        total = 0
        for ch in [os.path.join(src, c) for c in os.listdir(src)]:
            total += length(ch)
        return total
    return 0


print('Environment initialized successfully.')

# Configuration for data paths
raw_path = '/content/PPASR/raw_wav'  # Path to your raw, unsliced recordings

########################################

assert os.path.exists(raw_path) and os.path.isdir(raw_path), 'The chosen path does not exist or is not a directory.'
print('Raw recording path:', raw_path)
print()
print('===== Recording List =====')
raw_filelist = glob.glob(f'{raw_path}/*.wav', recursive=True)
raw_length = length(raw_path)
if len(raw_filelist) > 5:
    print('\n'.join(raw_filelist[:5] + [f'... ({len(raw_filelist) - 5} more)']))
else:
    print('\n'.join(raw_filelist))
print()
print(f'Found {len(raw_filelist)} valid recordings with total length of {round(raw_length, 2)} hours.')

sliced_path = '/content/PPASR/sliced_wav'  # Path to hold the sliced segments of your recordings

# Slicer arguments
db_threshold_ = -40. #@param {type:"string"}
min_length_ = 15000 #@param {type:"string"}
win_l_ = 800 #@param {type:"string"}
win_s_ = 40 #@param {type:"string"}
max_silence_kept_ = 1000 #@param {type:"string"}

# Number of threads (based on your CPU kernels)
num_workers = 5

########################################

assert 'raw_path' in locals().keys(), 'Raw path of your recordings has not been specified.'
assert not os.path.exists(sliced_path) or os.path.isdir(sliced_path), 'The chosen path is not a directory.'
os.makedirs(sliced_path, exist_ok=True)
print('Sliced recording path:', sliced_path)

from slicer import Slicer
from concurrent.futures import ThreadPoolExecutor, wait, ALL_COMPLETED

def slice_one(in_audio):
    audio, sr = librosa.load(in_audio, sr=None)
    slicer = Slicer(
        sr=sr,
        db_threshold=db_threshold_,
        min_length=min_length_,
        win_l=win_l_,
        win_s=win_s_,
        max_silence_kept=max_silence_kept_
    )
    chunks = slicer.slice(audio)
    for i, chunk in enumerate(chunks):
        soundfile.write(os.path.join(sliced_path, f'%s_slice_%04d.wav' % (os.path.basename(in_audio).rsplit('.', maxsplit=1)[0], i)), chunk, sr)


print('Slicing your recordings may take several minutes. Please wait.')
thread_pool = ThreadPoolExecutor(max_workers=num_workers)
tasks = []
for file in raw_filelist:
    tasks.append(thread_pool.submit(slice_one, file))
wait(tasks, return_when=ALL_COMPLETED)
print()
print('===== Segment List =====')
sliced_filelist = glob.glob(f'{sliced_path}/*.wav', recursive=True)
sliced_length = length(sliced_path)
if len(sliced_filelist) > 5:
    print('\n'.join(sliced_filelist[:5] + [f'... ({len(sliced_filelist) - 5} more)']))
else:
    print('\n'.join(sliced_filelist))
print()
print(f'Sliced your recordings into {len(sliced_filelist)} segments with total length of {round(sliced_length, 2)} hours.')

# %% [markdown]
# ---
#
#
#
# ---

# %% [markdown]
# ### 04 切片后的短音频自动转写

# %%
# %%shell
# cd /content/PPASR
# #ls ./sliced_wav/*.wav
#
# for file in ./sliced_wav/*.wav;  #一级目录下的内容-->并不递归显示！
#   do
#      python infer_path.py --wav_path=$file;  #${file}代表的是文件的全路径
#   done
# Out:
# ======================================================================
# 初始化解码器...
# language model: model path = lm/zh_giga.no_cna_cmn.prune01244.klm, is_character_based = True, max_order = 5, dict_size = 0
# 初始化解码器完成!
# ======================================================================
# [2022-12-20 15:23:51.423210 INFO   ] inference_predictor:__init__:71 - 已加载模型：models/conformer_online_fbank/infer/
# 消耗时间：654ms, 识别结果: 朋友是律师爸爸喜欢看书哥哥是医生我喜欢看电视, 得分: -3
# ======================================================================
# 初始化解码器...
# language model: model path = lm/zh_giga.no_cna_cmn.prune01244.klm, is_character_based = True, max_order = 5, dict_size = 0
# 初始化解码器完成!
# ======================================================================
# [2022-12-20 15:24:11.416380 INFO   ] inference_predictor:__init__:71 - 已加载模型：models/conformer_online_fbank/infer/
# 消耗时间：892ms, 识别结果: 他们是护士高鹏和徐涛是邻居他不叫高鹏, 得分: 2
# executing 'slice' costed 47.126s
# ======================================================================
# 初始化解码器...
# language model: model path = lm/zh_giga.no_cna_cmn.prune01244.klm, is_character_based = True, max_order = 5, dict_size = 0
# 初始化解码器完成!
# ======================================================================
# executing 'slice' costed 49.326s
# [2022-12-20 15:24:30.897274 INFO   ] inference_predictor:__init__:71 - 已加载模型：models/conformer_online_fbank/infer/
# executing 'slice' costed 61.389s
# 消耗时间：884ms, 识别结果: 弟弟喜欢跳舞打球可是我不喜欢打球许涛没有女儿, 得分: 0
# executing 'slice' costed 66.614s
# ======================================================================
# 初始化解码器...
# language model: model path = lm/zh_giga.no_cna_cmn.prune01244.klm, is_character_based = True, max_order = 5, dict_size = 0
# 初始化解码器完成!
# ======================================================================
# [2022-12-20 15:24:46.401789 INFO   ] inference_predictor:__init__:71 - 已加载模型：models/conformer_online_fbank/infer/
# 消耗时间：575ms, 识别结果: 我七点一之间联系朋友不是我们是邻居, 得分: 17
# ======================================================================
# 初始化解码器...
# language model: model path = lm/zh_giga.no_cna_cmn.prune01244.klm, is_character_based = True, max_order = 5, dict_size = 0
# 初始化解码器完成!
# ======================================================================
# [2022-12-20 15:24:59.252451 INFO   ] inference_predictor:__init__:71 - 已加载模型：models/conformer_online_fbank/infer/
# 消耗时间：691ms, 识别结果: 看书你这样的又一次吗八月八号是生子高鹏和, 得分: 9
# ======================================================================
# 初始化解码器...
# language model: model path = lm/zh_giga.no_cna_cmn.prune01244.klm, is_character_based = True, max_order = 5, dict_size = 0
# 初始化解码器完成!
# ======================================================================
# [2022-12-20 15:25:12.570418 INFO   ] inference_predictor:__init__:71 - 已加载模型：models/conformer_online_fbank/infer/
# 消耗时间：776ms, 识别结果: 徐涛是邻居我七点已改期间律师他们是护士打球可是我不喜欢打球, 得分: 21
# ======================================================================
# 初始化解码器...
# language model: model path = lm/zh_giga.no_cna_cmn.prune01244.klm, is_character_based = True, max_order = 5, dict_size = 0
# 初始化解码器完成!
# ======================================================================
# [2022-12-20 15:25:25.685333 INFO   ] inference_predictor:__init__:71 - 已加载模型：models/conformer_online_fbank/infer/
# 消耗时间：620ms, 识别结果: 我有一个女儿她不叫高朋朋友不是我们是邻居看书你这样的椅子吗, 得分: 7
# ======================================================================
# 初始化解码器...
# language model: model path = lm/zh_giga.no_cna_cmn.prune01244.klm, is_character_based = True, max_order = 5, dict_size = 0
# 初始化解码器完成!
# ======================================================================
# [2022-12-20 15:25:38.692677 INFO   ] inference_predictor:__init__:71 - 已加载模型：models/conformer_online_fbank/infer/
# 消耗时间：574ms, 识别结果: 我有一个女儿弟弟喜欢跳舞是她没有女儿爸爸喜欢看书哥哥是一生, 得分: 5
# ======================================================================
# 初始化解码器...
# language model: model path = lm/zh_giga.no_cna_cmn.prune01244.klm, is_character_based = True, max_order = 5, dict_size = 0
# 初始化解码器完成!
# ======================================================================
# [2022-12-20 15:25:51.430468 INFO   ] inference_predictor:__init__:71 - 已加载模型：models/conformer_online_fbank/infer/
# 消耗时间：439ms, 识别结果: 我喜欢看电视八月八号是星期五朋友是律师, 得分: -1
# ======================================================================
# 初始化解码器...
# language model: model path = lm/zh_giga.no_cna_cmn.prune01244.klm, is_character_based = True, max_order = 5, dict_size = 0
# 初始化解码器完成!
# ======================================================================
# [2022-12-20 15:26:04.242448 INFO   ] inference_predictor:__init__:71 - 已加载模型：models/conformer_online_fbank/infer/
# 消耗时间：535ms, 识别结果: 我叫木有房高峰是律师高峰住在二十六, 得分: -4
# ======================================================================
# 初始化解码器...
# language model: model path = lm/zh_giga.no_cna_cmn.prune01244.klm, is_character_based = True, max_order = 5, dict_size = 0
# 初始化解码器完成!
# ======================================================================
# [2022-12-20 15:26:17.074014 INFO   ] inference_predictor:__init__:71 - 已加载模型：models/conformer_online_fbank/infer/
# 消耗时间：536ms, 识别结果: 我我也在二楼住我是一个中文的学生我觉得学学中文还有一次, 得分: 7
# ======================================================================
# 初始化解码器...
# language model: model path = lm/zh_giga.no_cna_cmn.prune01244.klm, is_character_based = True, max_order = 5, dict_size = 0
# 初始化解码器完成!
# ======================================================================
# [2022-12-20 15:26:30.084220 INFO   ] inference_predictor:__init__:71 - 已加载模型：models/conformer_online_fbank/infer/
# 消耗时间：543ms, 识别结果: 我每天学习中文一思想这是一点一点点但是, 得分: 0
# ======================================================================
# 初始化解码器...
# language model: model path = lm/zh_giga.no_cna_cmn.prune01244.klm, is_character_based = True, max_order = 5, dict_size = 0
# 初始化解码器完成!
# ======================================================================
# [2022-12-20 15:26:42.845194 INFO   ] inference_predictor:__init__:71 - 已加载模型：models/conformer_online_fbank/infer/
# 消耗时间：422ms, 识别结果: 很好今天是十十九, 得分: -4
# ======================================================================
# 初始化解码器...
# language model: model path = lm/zh_giga.no_cna_cmn.prune01244.klm, is_character_based = True, max_order = 5, dict_size = 0
# 初始化解码器完成!
# ======================================================================
# [2022-12-20 15:26:55.511572 INFO   ] inference_predictor:__init__:71 - 已加载模型：models/conformer_online_fbank/infer/
# 消耗时间：563ms, 识别结果: 十九九今天是星期一是我不知道, 得分: 0
# ======================================================================
# 初始化解码器...
# language model: model path = lm/zh_giga.no_cna_cmn.prune01244.klm, is_character_based = True, max_order = 5, dict_size = 0
# 初始化解码器完成!
# ======================================================================
# [2022-12-20 15:27:08.307883 INFO   ] inference_predictor:__init__:71 - 已加载模型：models/conformer_online_fbank/infer/
# 消耗时间：792ms, 识别结果: 什么说下个时是二十一二十一号高峰的女儿喜欢跳舞, 得分: 16
# ======================================================================
# 初始化解码器...
# language model: model path = lm/zh_giga.no_cna_cmn.prune01244.klm, is_character_based = True, max_order = 5, dict_size = 0
# 初始化解码器完成!
# ======================================================================
# [2022-12-20 15:27:21.483647 INFO   ] inference_predictor:__init__:71 - 已加载模型：models/conformer_online_fbank/infer/
# 消耗时间：553ms, 识别结果: 他很喜欢俄罗斯的芭蕾她她很漂亮的她是很漂亮的女生, 得分: 14
# ======================================================================
# 初始化解码器...
# language model: model path = lm/zh_giga.no_cna_cmn.prune01244.klm, is_character_based = True, max_order = 5, dict_size = 0
# 初始化解码器完成!
# ======================================================================
# [2022-12-20 15:27:34.723826 INFO   ] inference_predictor:__init__:71 - 已加载模型：models/conformer_online_fbank/infer/
# 消耗时间：518ms, 识别结果: 哥哥喜欢看书弟弟喜欢看电视他看, 得分: -2
# ======================================================================
# 初始化解码器...
# language model: model path = lm/zh_giga.no_cna_cmn.prune01244.klm, is_character_based = True, max_order = 5, dict_size = 0
# 初始化解码器完成!
# ======================================================================
# [2022-12-20 15:27:47.718545 INFO   ] inference_predictor:__init__:71 - 已加载模型：models/conformer_online_fbank/infer/
# 消耗时间：650ms, 识别结果: 哥哥和弟弟在家好玩在北京现在, 得分: 3
# ======================================================================
# 初始化解码器...
# language model: model path = lm/zh_giga.no_cna_cmn.prune01244.klm, is_character_based = True, max_order = 5, dict_size = 0
# 初始化解码器完成!
# ======================================================================
# [2022-12-20 15:28:01.879964 INFO   ] inference_predictor:__init__:71 - 已加载模型：models/conformer_online_fbank/infer/
# 消耗时间：569ms, 识别结果: 十一三十在二十六现在五十五十三十, 得分: 0
# ======================================================================
# 初始化解码器...
# language model: model path = lm/zh_giga.no_cna_cmn.prune01244.klm, is_character_based = True, max_order = 5, dict_size = 0
# 初始化解码器完成!
# ======================================================================
# [2022-12-20 15:28:14.784499 INFO   ] inference_predictor:__init__:71 - 已加载模型：models/conformer_online_fbank/infer/
# 消耗时间：544ms, 识别结果: 北京比我说的时间六个小时, 得分: 6
# ======================================================================
# 初始化解码器...
# language model: model path = lm/zh_giga.no_cna_cmn.prune01244.klm, is_character_based = True, max_order = 5, dict_size = 0
# 初始化解码器完成!
# ======================================================================
# [2022-12-20 15:28:27.978793 INFO   ] inference_predictor:__init__:71 - 已加载模型：models/conformer_online_fbank/infer/
# 消耗时间：520ms, 识别结果: 朋友我们去吧喝酒好吗再走吧你可以用你的所收取, 得分: 1
# ======================================================================
# 初始化解码器...
# language model: model path = lm/zh_giga.no_cna_cmn.prune01244.klm, is_character_based = True, max_order = 5, dict_size = 0
# 初始化解码器完成!
# ======================================================================
# [2022-12-20 15:28:40.816473 INFO   ] inference_predictor:__init__:71 - 已加载模型：models/conformer_online_fbank/infer/
# 消耗时间：473ms, 识别结果: 喝啤酒朋友我们可以去打球了我们我们今天, 得分: -1
# ======================================================================
# 初始化解码器...
# language model: model path = lm/zh_giga.no_cna_cmn.prune01244.klm, is_character_based = True, max_order = 5, dict_size = 0
# 初始化解码器完成!
# ======================================================================
# [2022-12-20 15:28:53.747850 INFO   ] inference_predictor:__init__:71 - 已加载模型：models/conformer_online_fbank/infer/
# 消耗时间：238ms, 识别结果: 去去巴拉那州吧好吗, 得分: 7
# ======================================================================
# 初始化解码器...
# language model: model path = lm/zh_giga.no_cna_cmn.prune01244.klm, is_character_based = True, max_order = 5, dict_size = 0
# 初始化解码器完成!
# ======================================================================
# [2022-12-20 15:29:06.424658 INFO   ] inference_predictor:__init__:71 - 已加载模型：models/conformer_online_fbank/infer/
# 消耗时间：505ms, 识别结果: 朋友是李氏爸爸喜欢看书格格是一生不喜欢看电视, 得分: 0
# ======================================================================
# 初始化解码器...
# language model: model path = lm/zh_giga.no_cna_cmn.prune01244.klm, is_character_based = True, max_order = 5, dict_size = 0
# 初始化解码器完成!
# ======================================================================
# [2022-12-20 15:29:19.337054 INFO   ] inference_predictor:__init__:71 - 已加载模型：models/conformer_online_fbank/infer/
# 消耗时间：571ms, 识别结果: 他们是护士高鹏和徐涛是邻居他不叫高峰, 得分: 1
# ======================================================================
# 初始化解码器...
# language model: model path = lm/zh_giga.no_cna_cmn.prune01244.klm, is_character_based = True, max_order = 5, dict_size = 0
# 初始化解码器完成!
# ======================================================================
# [2022-12-20 15:29:32.244845 INFO   ] inference_predictor:__init__:71 - 已加载模型：models/conformer_online_fbank/infer/
# 消耗时间：665ms, 识别结果: 弟弟喜欢跳舞打球可是我不喜欢打球才没有女人, 得分: 14
# ======================================================================
# 初始化解码器...
# language model: model path = lm/zh_giga.no_cna_cmn.prune01244.klm, is_character_based = True, max_order = 5, dict_size = 0
# 初始化解码器完成!
# ======================================================================
# [2022-12-20 15:29:45.403310 INFO   ] inference_predictor:__init__:71 - 已加载模型：models/conformer_online_fbank/infer/
# 消耗时间：562ms, 识别结果: 我七点一刻去见李石朋友不是我们是邻居看书你觉得有意思吗, 得分: 2
# ======================================================================
# 初始化解码器...
# language model: model path = lm/zh_giga.no_cna_cmn.prune01244.klm, is_character_based = True, max_order = 5, dict_size = 0
# 初始化解码器完成!
# ======================================================================
# [2022-12-20 15:29:58.050731 INFO   ] inference_predictor:__init__:71 - 已加载模型：models/conformer_online_fbank/infer/
# 消耗时间：618ms, 识别结果: 八月八号是星期五老峰和徐涛是邻居我七点一刻去见李世, 得分: 10
# ======================================================================
# 初始化解码器...
# language model: model path = lm/zh_giga.no_cna_cmn.prune01244.klm, is_character_based = True, max_order = 5, dict_size = 0
# 初始化解码器完成!
# ======================================================================
# [2022-12-20 15:30:10.951119 INFO   ] inference_predictor:__init__:71 - 已加载模型：models/conformer_online_fbank/infer/
# 消耗时间：520ms, 识别结果: 他们是护士打球可是我不喜欢打球我有一个女儿他不叫高鹏, 得分: 10
# ======================================================================
# 初始化解码器...
# language model: model path = lm/zh_giga.no_cna_cmn.prune01244.klm, is_character_based = True, max_order = 5, dict_size = 0
# 初始化解码器完成!
# ======================================================================
# [2022-12-20 15:30:23.674533 INFO   ] inference_predictor:__init__:71 - 已加载模型：models/conformer_online_fbank/infer/
# 消耗时间：520ms, 识别结果: 朋友不是我们是邻居看书你觉得有意思吗我有一个女儿, 得分: 0
# ======================================================================
# 初始化解码器...
# language model: model path = lm/zh_giga.no_cna_cmn.prune01244.klm, is_character_based = True, max_order = 5, dict_size = 0
# 初始化解码器完成!
# ======================================================================
# [2022-12-20 15:30:36.420875 INFO   ] inference_predictor:__init__:71 - 已加载模型：models/conformer_online_fbank/infer/
# 消耗时间：503ms, 识别结果: 弟弟喜欢跳舞许涛没有女儿爸爸喜欢看书哥哥是医生, 得分: -3
# ======================================================================
# 初始化解码器...
# language model: model path = lm/zh_giga.no_cna_cmn.prune01244.klm, is_character_based = True, max_order = 5, dict_size = 0
# 初始化解码器完成!
# ======================================================================
# [2022-12-20 15:30:49.491440 INFO   ] inference_predictor:__init__:71 - 已加载模型：models/conformer_online_fbank/infer/
# 消耗时间：919ms, 识别结果: 我喜欢看电视八月八号是星期五朋友是你是他叫高峰, 得分: 2
# ======================================================================
# 初始化解码器...
# language model: model path = lm/zh_giga.no_cna_cmn.prune01244.klm, is_character_based = True, max_order = 5, dict_size = 0
# 初始化解码器完成!
# ======================================================================
# [2022-12-20 15:31:02.695107 INFO   ] inference_predictor:__init__:71 - 已加载模型：models/conformer_online_fbank/infer/
# 消耗时间：550ms, 识别结果: 高峰是李氏在北京高峰的电话号码是八五八七五八七五, 得分: 9
# ======================================================================
# 初始化解码器...
# language model: model path = lm/zh_giga.no_cna_cmn.prune01244.klm, is_character_based = True, max_order = 5, dict_size = 0
# 初始化解码器完成!
# ======================================================================
# [2022-12-20 15:31:15.441597 INFO   ] inference_predictor:__init__:71 - 已加载模型：models/conformer_online_fbank/infer/
# 消耗时间：796ms, 识别结果: 今天是八月一号今天是星期一今天也是今天是周一高中的女儿喜欢跳舞, 得分: 0
# ======================================================================
# 初始化解码器...
# language model: model path = lm/zh_giga.no_cna_cmn.prune01244.klm, is_character_based = True, max_order = 5, dict_size = 0
# 初始化解码器完成!
# ======================================================================
# [2022-12-20 15:31:28.522867 INFO   ] inference_predictor:__init__:71 - 已加载模型：models/conformer_online_fbank/infer/
# 消耗时间：457ms, 识别结果: 他穿白色的衣服哥哥喜欢看书, 得分: -4
# ======================================================================
# 初始化解码器...
# language model: model path = lm/zh_giga.no_cna_cmn.prune01244.klm, is_character_based = True, max_order = 5, dict_size = 0
# 初始化解码器完成!
# ======================================================================
# [2022-12-20 15:31:41.159530 INFO   ] inference_predictor:__init__:71 - 已加载模型：models/conformer_online_fbank/infer/
# 消耗时间：1004ms, 识别结果: 弟弟喜欢看电视哥哥被滴滴滴滴不太聪明北京现在是一点, 得分: 12
# ======================================================================
# 初始化解码器...
# language model: model path = lm/zh_giga.no_cna_cmn.prune01244.klm, is_character_based = True, max_order = 5, dict_size = 0
# 初始化解码器完成!
# ======================================================================
# [2022-12-20 15:31:54.638701 INFO   ] inference_predictor:__init__:71 - 已加载模型：models/conformer_online_fbank/infer/
# 消耗时间：512ms, 识别结果: 二十五现在六点半我们去听音乐会吧好吗, 得分: 3
# ======================================================================
# 初始化解码器...
# language model: model path = lm/zh_giga.no_cna_cmn.prune01244.klm, is_character_based = True, max_order = 5, dict_size = 0
# 初始化解码器完成!
# ======================================================================
# [2022-12-20 15:32:07.410819 INFO   ] inference_predictor:__init__:71 - 已加载模型：models/conformer_online_fbank/infer/
# 消耗时间：289ms, 识别结果: 我们去乒乓球吧好吗我们去玩乒乓球好, 得分: 0
# ======================================================================
# 初始化解码器...
# language model: model path = lm/zh_giga.no_cna_cmn.prune01244.klm, is_character_based = True, max_order = 5, dict_size = 0
# 初始化解码器完成!
# ======================================================================
# [2022-12-20 15:32:20.029323 INFO   ] inference_predictor:__init__:71 - 已加载模型：models/conformer_online_fbank/infer/
# 消耗时间：472ms, 识别结果: 朋友是律师爸爸喜欢看书哥哥是医生我喜欢看电视他们是护士, 得分: -5
# ======================================================================
# 初始化解码器...
# language model: model path = lm/zh_giga.no_cna_cmn.prune01244.klm, is_character_based = True, max_order = 5, dict_size = 0
# 初始化解码器完成!
# ======================================================================
# [2022-12-20 15:32:32.664184 INFO   ] inference_predictor:__init__:71 - 已加载模型：models/conformer_online_fbank/infer/
# 消耗时间：587ms, 识别结果: 高鹏和许涛是邻居他不叫高鹏弟弟喜欢跳舞打球可是我不喜欢打球许涛没有女儿, 得分: -5
# ======================================================================
# 初始化解码器...
# language model: model path = lm/zh_giga.no_cna_cmn.prune01244.klm, is_character_based = True, max_order = 5, dict_size = 0
# 初始化解码器完成!
# ======================================================================
# [2022-12-20 15:32:45.412646 INFO   ] inference_predictor:__init__:71 - 已加载模型：models/conformer_online_fbank/infer/
# 消耗时间：509ms, 识别结果: 我七点一刻去见律师朋友不是我们是邻居看书你觉得有意思吗八月八号是星期五, 得分: -5
# ======================================================================
# 初始化解码器...
# language model: model path = lm/zh_giga.no_cna_cmn.prune01244.klm, is_character_based = True, max_order = 5, dict_size = 0
# 初始化解码器完成!
# ======================================================================
# [2022-12-20 15:32:57.765247 INFO   ] inference_predictor:__init__:71 - 已加载模型：models/conformer_online_fbank/infer/
# 消耗时间：471ms, 识别结果: 高鹏和许涛是邻居我七点一刻去见律师他们是护士打球可是我不喜欢打球, 得分: -3
# ======================================================================
# 初始化解码器...
# language model: model path = lm/zh_giga.no_cna_cmn.prune01244.klm, is_character_based = True, max_order = 5, dict_size = 0
# 初始化解码器完成!
# ======================================================================
# [2022-12-20 15:33:10.808550 INFO   ] inference_predictor:__init__:71 - 已加载模型：models/conformer_online_fbank/infer/
# 消耗时间：514ms, 识别结果: 我有一个女儿她不叫高朋朋友不是我们是邻居看书你觉得有意思吗我有一个女儿, 得分: 0
# ======================================================================
# 初始化解码器...
# language model: model path = lm/zh_giga.no_cna_cmn.prune01244.klm, is_character_based = True, max_order = 5, dict_size = 0
# 初始化解码器完成!
# ======================================================================
# [2022-12-20 15:33:23.401321 INFO   ] inference_predictor:__init__:71 - 已加载模型：models/conformer_online_fbank/infer/
# 消耗时间：487ms, 识别结果: 弟弟喜欢跳舞许涛没有女儿爸爸喜欢看书哥哥是医生我喜欢看电视, 得分: -4
# ======================================================================
# 初始化解码器...
# language model: model path = lm/zh_giga.no_cna_cmn.prune01244.klm, is_character_based = True, max_order = 5, dict_size = 0
# 初始化解码器完成!
# ======================================================================
# [2022-12-20 15:33:36.051621 INFO   ] inference_predictor:__init__:71 - 已加载模型：models/conformer_online_fbank/infer/
# 消耗时间：1143ms, 识别结果: 八月八号是星期五朋友是律师他叫高峰高峰是律师高鹏在北京工作, 得分: 2
# ======================================================================
# 初始化解码器...
# language model: model path = lm/zh_giga.no_cna_cmn.prune01244.klm, is_character_based = True, max_order = 5, dict_size = 0
# 初始化解码器完成!
# ======================================================================
# [2022-12-20 15:33:51.181874 INFO   ] inference_predictor:__init__:71 - 已加载模型：models/conformer_online_fbank/infer/
# 消耗时间：537ms, 识别结果: 今天是八月一号今天是星期一高鹏的女儿喜欢跳舞哥哥喜欢看书弟弟喜欢看电视, 得分: -3
# ======================================================================
# 初始化解码器...
# language model: model path = lm/zh_giga.no_cna_cmn.prune01244.klm, is_character_based = True, max_order = 5, dict_size = 0
# 初始化解码器完成!
# ======================================================================
# [2022-12-20 15:34:03.841234 INFO   ] inference_predictor:__init__:71 - 已加载模型：models/conformer_online_fbank/infer/
# 消耗时间：1112ms, 识别结果: 北京现在是十一点三十分奥斯路现在是五点三十分我们去听音乐会吧好吗, 得分: -2
# ======================================================================
# 初始化解码器...
# language model: model path = lm/zh_giga.no_cna_cmn.prune01244.klm, is_character_based = True, max_order = 5, dict_size = 0
# 初始化解码器完成!
# ======================================================================
# [2022-12-20 15:34:17.464435 INFO   ] inference_predictor:__init__:71 - 已加载模型：models/conformer_online_fbank/infer/
# 消耗时间：130ms, 识别结果: 我们去打乒乓球吧好吗, 得分: 4
# ======================================================================
# 初始化解码器...
# language model: model path = lm/zh_giga.no_cna_cmn.prune01244.klm, is_character_based = True, max_order = 5, dict_size = 0
# 初始化解码器完成!
# ======================================================================
# [2022-12-20 15:34:29.757011 INFO   ] inference_predictor:__init__:71 - 已加载模型：models/conformer_online_fbank/infer/
# 消耗时间：501ms, 识别结果: 朋友是律师爸爸喜欢看书哥哥是医生我喜欢看电视, 得分: -4
# ======================================================================
# 初始化解码器...
# language model: model path = lm/zh_giga.no_cna_cmn.prune01244.klm, is_character_based = True, max_order = 5, dict_size = 0
# 初始化解码器完成!
# ======================================================================
# [2022-12-20 15:34:42.377626 INFO   ] inference_predictor:__init__:71 - 已加载模型：models/conformer_online_fbank/infer/
# 消耗时间：456ms, 识别结果: 他们是护士高鹏和徐涛是邻居他不叫高鹏, 得分: -1
# ======================================================================
# 初始化解码器...
# language model: model path = lm/zh_giga.no_cna_cmn.prune01244.klm, is_character_based = True, max_order = 5, dict_size = 0
# 初始化解码器完成!
# ======================================================================
# [2022-12-20 15:34:54.969921 INFO   ] inference_predictor:__init__:71 - 已加载模型：models/conformer_online_fbank/infer/
# 消耗时间：459ms, 识别结果: 弟弟喜欢跳舞打球可是我不喜欢打球徐涛没有女儿我七点一刻去见律师, 得分: -5
# ======================================================================
# 初始化解码器...
# language model: model path = lm/zh_giga.no_cna_cmn.prune01244.klm, is_character_based = True, max_order = 5, dict_size = 0
# 初始化解码器完成!
# ======================================================================
# [2022-12-20 15:35:07.477562 INFO   ] inference_predictor:__init__:71 - 已加载模型：models/conformer_online_fbank/infer/
# 消耗时间：598ms, 识别结果: 朋友不是我们是邻居看书你觉得有意思吗八月八号是星期五高鹏和徐涛是邻居, 得分: -5
# ======================================================================
# 初始化解码器...
# language model: model path = lm/zh_giga.no_cna_cmn.prune01244.klm, is_character_based = True, max_order = 5, dict_size = 0
# 初始化解码器完成!
# ======================================================================
# [2022-12-20 15:35:20.155739 INFO   ] inference_predictor:__init__:71 - 已加载模型：models/conformer_online_fbank/infer/
# 消耗时间：490ms, 识别结果: 我七点一刻去见律师他们是护士打球可是我不喜欢打球, 得分: -4
# ======================================================================
# 初始化解码器...
# language model: model path = lm/zh_giga.no_cna_cmn.prune01244.klm, is_character_based = True, max_order = 5, dict_size = 0
# 初始化解码器完成!
# ======================================================================
# [2022-12-20 15:35:33.065138 INFO   ] inference_predictor:__init__:71 - 已加载模型：models/conformer_online_fbank/infer/
# 消耗时间：444ms, 识别结果: 我有一个女儿她不叫高朋朋友不是我们是邻居, 得分: -2
# ======================================================================
# 初始化解码器...
# language model: model path = lm/zh_giga.no_cna_cmn.prune01244.klm, is_character_based = True, max_order = 5, dict_size = 0
# 初始化解码器完成!
# ======================================================================
# [2022-12-20 15:35:46.415661 INFO   ] inference_predictor:__init__:71 - 已加载模型：models/conformer_online_fbank/infer/
# 消耗时间：445ms, 识别结果: 看书你觉得有意思吗我有一个女儿弟弟喜欢跳舞徐涛没有女儿爸爸喜欢看书, 得分: -4
# ======================================================================
# 初始化解码器...
# language model: model path = lm/zh_giga.no_cna_cmn.prune01244.klm, is_character_based = True, max_order = 5, dict_size = 0
# 初始化解码器完成!
# ======================================================================
# [2022-12-20 15:35:58.951386 INFO   ] inference_predictor:__init__:71 - 已加载模型：models/conformer_online_fbank/infer/
# 消耗时间：443ms, 识别结果: 哥哥是医生我喜欢看电视八月八号是星期五朋友是律师他叫高鹏, 得分: -1
# ======================================================================
# 初始化解码器...
# language model: model path = lm/zh_giga.no_cna_cmn.prune01244.klm, is_character_based = True, max_order = 5, dict_size = 0
# 初始化解码器完成!
# ======================================================================
# [2022-12-20 15:36:11.456272 INFO   ] inference_predictor:__init__:71 - 已加载模型：models/conformer_online_fbank/infer/
# 消耗时间：532ms, 识别结果: 高鹏是一名律师高鹏在北京市今天是八月一号, 得分: -5
# ======================================================================
# 初始化解码器...
# language model: model path = lm/zh_giga.no_cna_cmn.prune01244.klm, is_character_based = True, max_order = 5, dict_size = 0
# 初始化解码器完成!
# ======================================================================
# [2022-12-20 15:36:24.074506 INFO   ] inference_predictor:__init__:71 - 已加载模型：models/conformer_online_fbank/infer/
# 消耗时间：437ms, 识别结果: 今天是星期一高鹏的女儿喜欢跳舞哥哥喜欢看书, 得分: -5
# ======================================================================
# 初始化解码器...
# language model: model path = lm/zh_giga.no_cna_cmn.prune01244.klm, is_character_based = True, max_order = 5, dict_size = 0
# 初始化解码器完成!
# ======================================================================
# [2022-12-20 15:36:36.569171 INFO   ] inference_predictor:__init__:71 - 已加载模型：models/conformer_online_fbank/infer/
# 消耗时间：433ms, 识别结果: 弟弟喜欢看电视北京现在十一点半奥斯路现在五点半, 得分: -5
# ======================================================================
# 初始化解码器...
# language model: model path = lm/zh_giga.no_cna_cmn.prune01244.klm, is_character_based = True, max_order = 5, dict_size = 0
# 初始化解码器完成!
# ======================================================================
# [2022-12-20 15:36:49.069689 INFO   ] inference_predictor:__init__:71 - 已加载模型：models/conformer_online_fbank/infer/
# 消耗时间：228ms, 识别结果: 去音乐会吧好吗去打乒乓球吧好吗, 得分: -2

# %%
import os
import sys
import numpy as np
from pypinyin import pinyin, lazy_pinyin, Style
import re

root_dir = "/content/PPASR/sliced_wav"
pattern = re.compile(r'(.*)\.txt$')
r="[_.!+-=——,$%^,。?、~@#￥%……&*《》<>「」{}【】()（）/''\n ]"

for root, dir, files in os.walk(root_dir):
	for filename in files:
		#print(filename)
		output = pattern.match(filename)
		if output is not None:
			print(root, filename)
			text_file = open(root+"/"+filename)
			line = text_file.read().strip()
			line = line.replace("，", "")
			line = re.sub(r,"",line)
			pinyin =  lazy_pinyin(line, style=Style.TONE3, errors='default', strict=False, v_to_u=False, neutral_tone_with_five=True,tone_sandhi=True)
			pinyinline = ' '.join(pinyin)
			print(line)
			target_text_file = open(root+"/"+output.group(1)+".txt", "w")
			target_text_file.write(pinyinline)
			target_text_file.close()
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting pypinyin
#   Downloading pypinyin-0.47.1-py2.py3-none-any.whl (1.4 MB)
#      |████████████████████████████████| 1.4 MB 31.8 MB/s
# Installing collected packages: pypinyin
# Successfully installed pypinyin-0.47.1
# /content/PPASR/sliced_wav alv0805_slice_0007.txt
# 弟弟喜欢跳舞许涛没有女儿爸爸喜欢看书哥哥是医生
# /content/PPASR/sliced_wav lj1216_slice_0001.txt
# 他们是护士高鹏和徐涛是邻居他不叫高鹏
# /content/PPASR/sliced_wav hp0317_slice_0003.txt
# 高鹏和许涛是邻居我七点一刻去见律师他们是护士打球可是我不喜欢打球
# /content/PPASR/sliced_wav aam0511_slice_0009.txt
# 我叫木有房高峰是律师高峰住在二十六
# /content/PPASR/sliced_wav aam0511_slice_0010.txt
# 我我也在二楼住我是一个中文的学生我觉得学学中文还有一次
# /content/PPASR/sliced_wav alv0805_slice_0002.txt
# 弟弟喜欢跳舞打球可是我不喜欢打球才没有女人
# /content/PPASR/sliced_wav lj1216_slice_0007.txt
# 哥哥是医生我喜欢看电视八月八号是星期五朋友是律师他叫高鹏
# /content/PPASR/sliced_wav aam0511_slice_0018.txt
# 十一三十在二十六现在五十五十三十
# /content/PPASR/sliced_wav alv0805_slice_0013.txt
# 二十五现在六点半我们去听音乐会吧好吗
# /content/PPASR/sliced_wav alv0805_slice_0000.txt
# 朋友是李氏爸爸喜欢看书格格是一生不喜欢看电视
# /content/PPASR/sliced_wav aam0511_slice_0006.txt
# 我有一个女儿她不叫高朋朋友不是我们是邻居看书你这样的椅子吗
# /content/PPASR/sliced_wav alv0805_slice_0014.txt
# 我们去乒乓球吧好吗我们去玩乒乓球好
# /content/PPASR/sliced_wav lj1216_slice_0004.txt
# 我七点一刻去见律师他们是护士打球可是我不喜欢打球
# /content/PPASR/sliced_wav lj1216_slice_0006.txt
# 看书你觉得有意思吗我有一个女儿弟弟喜欢跳舞徐涛没有女儿爸爸喜欢看书
# /content/PPASR/sliced_wav alv0805_slice_0005.txt
# 他们是护士打球可是我不喜欢打球我有一个女儿他不叫高鹏
# /content/PPASR/sliced_wav lj1216_slice_0000.txt
# 朋友是律师爸爸喜欢看书哥哥是医生我喜欢看电视
# /content/PPASR/sliced_wav alv0805_slice_0003.txt
# 我七点一刻去见李石朋友不是我们是邻居看书你觉得有意思吗
# /content/PPASR/sliced_wav aam0511_slice_0012.txt
# 很好今天是十十九
# /content/PPASR/sliced_wav lj1216_slice_0005.txt
# 我有一个女儿她不叫高朋朋友不是我们是邻居
# /content/PPASR/sliced_wav alv0805_slice_0008.txt
# 我喜欢看电视八月八号是星期五朋友是你是他叫高峰
# /content/PPASR/sliced_wav lj1216_slice_0009.txt
# 今天是星期一高鹏的女儿喜欢跳舞哥哥喜欢看书
# /content/PPASR/sliced_wav hp0317_slice_0006.txt
# 八月八号是星期五朋友是律师他叫高峰高峰是律师高鹏在北京工作
# /content/PPASR/sliced_wav lj1216_slice_0010.txt
# 弟弟喜欢看电视北京现在十一点半奥斯路现在五点半
# /content/PPASR/sliced_wav alv0805_slice_0004.txt
# 八月八号是星期五老峰和徐涛是邻居我七点一刻去见李世
# /content/PPASR/sliced_wav aam0511_slice_0007.txt
# 我有一个女儿弟弟喜欢跳舞是她没有女儿爸爸喜欢看书哥哥是一生
# /content/PPASR/sliced_wav hp0317_slice_0004.txt
# 我有一个女儿她不叫高朋朋友不是我们是邻居看书你觉得有意思吗我有一个女儿
# /content/PPASR/sliced_wav lj1216_slice_0011.txt
# 去音乐会吧好吗去打乒乓球吧好吗
# /content/PPASR/sliced_wav lj1216_slice_0008.txt
# 高鹏是一名律师高鹏在北京市今天是八月一号
# /content/PPASR/sliced_wav aam0511_slice_0003.txt
# 我七点一之间联系朋友不是我们是邻居
# /content/PPASR/sliced_wav hp0317_slice_0007.txt
# 今天是八月一号今天是星期一高鹏的女儿喜欢跳舞哥哥喜欢看书弟弟喜欢看电视
# /content/PPASR/sliced_wav aam0511_slice_0004.txt
# 看书你这样的又一次吗八月八号是生子高鹏和
# /content/PPASR/sliced_wav aam0511_slice_0015.txt
# 他很喜欢俄罗斯的芭蕾她她很漂亮的她是很漂亮的女生
# /content/PPASR/sliced_wav aam0511_slice_0013.txt
# 十九九今天是星期一是我不知道
# /content/PPASR/sliced_wav alv0805_slice_0012.txt
# 弟弟喜欢看电视哥哥被滴滴滴滴不太聪明北京现在是一点
# /content/PPASR/sliced_wav aam0511_slice_0014.txt
# 什么说下个时是二十一二十一号高峰的女儿喜欢跳舞
# /content/PPASR/sliced_wav aam0511_slice_0022.txt
# 去去巴拉那州吧好吗
# /content/PPASR/sliced_wav alv0805_slice_0011.txt
# 他穿白色的衣服哥哥喜欢看书
# /content/PPASR/sliced_wav aam0511_slice_0021.txt
# 喝啤酒朋友我们可以去打球了我们我们今天
# /content/PPASR/sliced_wav hp0317_slice_0009.txt
# 我们去打乒乓球吧好吗
# /content/PPASR/sliced_wav aam0511_slice_0016.txt
# 哥哥喜欢看书弟弟喜欢看电视他看
# /content/PPASR/sliced_wav aam0511_slice_0000.txt
# 朋友是律师爸爸喜欢看书哥哥是医生我喜欢看电视
# /content/PPASR/sliced_wav hp0317_slice_0000.txt
# 朋友是律师爸爸喜欢看书哥哥是医生我喜欢看电视他们是护士
# /content/PPASR/sliced_wav alv0805_slice_0006.txt
# 朋友不是我们是邻居看书你觉得有意思吗我有一个女儿
# /content/PPASR/sliced_wav lj1216_slice_0003.txt
# 朋友不是我们是邻居看书你觉得有意思吗八月八号是星期五高鹏和徐涛是邻居
# /content/PPASR/sliced_wav aam0511_slice_0005.txt
# 徐涛是邻居我七点已改期间律师他们是护士打球可是我不喜欢打球
# /content/PPASR/sliced_wav aam0511_slice_0001.txt
# 他们是护士高鹏和徐涛是邻居他不叫高鹏
# /content/PPASR/sliced_wav aam0511_slice_0011.txt
# 我每天学习中文一思想这是一点一点点但是
# /content/PPASR/sliced_wav hp0317_slice_0001.txt
# 高鹏和许涛是邻居他不叫高鹏弟弟喜欢跳舞打球可是我不喜欢打球许涛没有女儿
# /content/PPASR/sliced_wav aam0511_slice_0017.txt
# 哥哥和弟弟在家好玩在北京现在
# /content/PPASR/sliced_wav hp0317_slice_0002.txt
# 我七点一刻去见律师朋友不是我们是邻居看书你觉得有意思吗八月八号是星期五
# /content/PPASR/sliced_wav aam0511_slice_0002.txt
# 弟弟喜欢跳舞打球可是我不喜欢打球许涛没有女儿
# /content/PPASR/sliced_wav alv0805_slice_0001.txt
# 他们是护士高鹏和徐涛是邻居他不叫高峰
# /content/PPASR/sliced_wav aam0511_slice_0019.txt
# 北京比我说的时间六个小时
# /content/PPASR/sliced_wav aam0511_slice_0008.txt
# 我喜欢看电视八月八号是星期五朋友是律师
# /content/PPASR/sliced_wav alv0805_slice_0010.txt
# 今天是八月一号今天是星期一今天也是今天是周一高中的女儿喜欢跳舞
# /content/PPASR/sliced_wav lj1216_slice_0002.txt
# 弟弟喜欢跳舞打球可是我不喜欢打球徐涛没有女儿我七点一刻去见律师
# /content/PPASR/sliced_wav hp0317_slice_0005.txt
# 弟弟喜欢跳舞许涛没有女儿爸爸喜欢看书哥哥是医生我喜欢看电视
# /content/PPASR/sliced_wav hp0317_slice_0008.txt
# 北京现在是十一点三十分奥斯路现在是五点三十分我们去听音乐会吧好吗
# /content/PPASR/sliced_wav aam0511_slice_0020.txt
# 朋友我们去吧喝酒好吗再走吧你可以用你的所收取
# /content/PPASR/sliced_wav alv0805_slice_0009.txt
# 高峰是李氏在北京高峰的电话号码是八五八七五八七五

# %%
#from IPython.display import Audio
#wn = Audio('/content/PPASR/sliced_wav/aam0511_slice_0006.wav', autoplay=True)
#with open('/content/PPASR/sliced_wav/aam0511_slice_0006.txt', 'r') as f:
    print(f.read())
#display(wn)

# %% [markdown]
# ### 05 保存短音频和对应转写到谷歌云盘

# %%
import os, tarfile
import os
from google.colab import files
save_as = 'mfa_prepare.tar'#@param {type:"string"}
def make_targz_one_by_one(output_filename, source_dir):
  tar = tarfile.open(output_filename,"w")
  for root,dir_name,files_list in os.walk(source_dir):
    for file in files_list:
      pathfile = os.path.join(root, file)
      tar.add(pathfile)
  tar.close()
 
  # files.download(output_filename)
 
make_targz_one_by_one(save_as , '/content/PPASR/sliced_wav')
savename = "/content/PPASR" + save_as
# !cp -r savename /content/drive/MyDrive
